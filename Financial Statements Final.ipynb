# %% [markdown]
# # Income Statement

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Fetch revenue data
symbol = 'HSY'
hershey = yf.Ticker(symbol)

# Get income statement data (focus on revenues)
income_statement = hershey.financials
revenue_data = income_statement.loc['Total Revenue'].transpose()

# Display the revenue data
print("Hershey's Revenue Data (in billions):")
print(revenue_data)

# Check for NaN values in revenue data
if revenue_data.isnull().any():
    print("\nWarning: NaN values detected in revenue data. Handling them...")
    revenue_data = revenue_data.dropna()  # Drop rows with NaN values
    # Alternatively, you could fill NaN values with the mean or median:
    # revenue_data = revenue_data.fillna(revenue_data.mean())

# Prepare data for regression
# Convert index to datetime for better handling
revenue_data.index = pd.to_datetime(revenue_data.index)
revenue_data = revenue_data.sort_index()

# Create a numerical index for regression
X = np.array(range(len(revenue_data))).reshape(-1, 1)  # Independent variable (time)
y = revenue_data.values  # Dependent variable (revenue)

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict future revenues (for the next 3 years)
future_X = np.array(range(len(revenue_data), len(revenue_data) + 3)).reshape(-1, 1)  # Next 3 years
predicted_revenue = model.predict(future_X)

# Combine historical and predicted revenues
future_dates = pd.date_range(start=revenue_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
predicted_revenue_series = pd.Series(predicted_revenue, index=future_dates)

# Plot historical and predicted revenues
plt.figure(figsize=(10, 5))
plt.plot(revenue_data.index, revenue_data.values, label='Historical Revenue', marker='o')
plt.plot(predicted_revenue_series.index, predicted_revenue_series.values, label='Predicted Revenue', marker='o', linestyle='--')
plt.title("Hershey's Revenue Prediction")
plt.xlabel("Year")
plt.ylabel("Revenue (in billions)")
plt.legend()
plt.grid()
plt.show()

# Print predicted revenues
print("\nPredicted Revenues for the Next 3 Years:")
for year, revenue in zip(predicted_revenue_series.index.year, predicted_revenue_series.values):
    print(f"{year}: ${revenue:.2f} billion")
# Out:
# Hershey's Revenue Data (in billions):
# 2024-12-31    11202263000.0
# 2023-12-31    11164992000.0
# 2022-12-31    10419294000.0
# 2021-12-31     8971337000.0
# 2020-12-31              NaN
# Name: Total Revenue, dtype: object
#
# Warning: NaN values detected in revenue data. Handling them...
# C:\Users\rober\AppData\Local\Temp\ipykernel_21188\4222915795.py:44: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   future_dates = pd.date_range(start=revenue_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
# Predicted Revenues for the Next 3 Years:
# 2025: $12299090500.00 billion
# 2026: $13042938100.00 billion
# 2027: $13786785700.00 billion

# %%
# Get income statement data (focus on Diluted EPS)
income_statement = hershey.financials
eps_data = income_statement.loc['Diluted EPS'].transpose()

# Display the EPS data
print("Hershey's Diluted EPS Data (in dollars):")
print(eps_data)

# Check for NaN values in EPS data
if eps_data.isnull().any():
    print("\nWarning: NaN values detected in Diluted EPS data. Handling them...")
    eps_data = eps_data.dropna()  # Drop rows with NaN values
    # Alternatively, you could fill NaN values with the mean or median:
    # eps_data = eps_data.fillna(eps_data.mean())

# Prepare data for regression
# Convert index to datetime for better handling
eps_data.index = pd.to_datetime(eps_data.index)
eps_data = eps_data.sort_index()

# Create a numerical index for regression
X = np.array(range(len(eps_data))).reshape(-1, 1)  # Independent variable (time)
y = eps_data.values  # Dependent variable (Diluted EPS)

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict future EPS (for the next 3 years)
future_X = np.array(range(len(eps_data), len(eps_data) + 3)).reshape(-1, 1)  # Next 3 years
predicted_eps = model.predict(future_X)

# Combine historical and predicted EPS
future_dates = pd.date_range(start=eps_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
predicted_eps_series = pd.Series(predicted_eps, index=future_dates)

# Plot historical and predicted EPS
plt.figure(figsize=(10, 5))
plt.plot(eps_data.index, eps_data.values, label='Historical Diluted EPS', marker='o')
plt.plot(predicted_eps_series.index, predicted_eps_series.values, label='Predicted Diluted EPS', marker='o', linestyle='--')
plt.title("Hershey's Diluted EPS Prediction")
plt.xlabel("Year")
plt.ylabel("Diluted EPS (in dollars)")
plt.legend()
plt.grid()
plt.show()

# Print predicted EPS
print("\nPredicted Diluted EPS for the Next 3 Years:")
for year, eps in zip(predicted_eps_series.index.year, predicted_eps_series.values):
    print(f"{year}: ${eps:.2f}")
# Out:
# Hershey's Diluted EPS Data (in dollars):
# 2024-12-31     NaN
# 2023-12-31    9.06
# 2022-12-31    7.96
# 2021-12-31    7.11
# 2020-12-31    6.11
# Name: Diluted EPS, dtype: object
#
# Warning: NaN values detected in Diluted EPS data. Handling them...
# C:\Users\rober\AppData\Local\Temp\ipykernel_21188\1860011975.py:34: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   future_dates = pd.date_range(start=eps_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
# Predicted Diluted EPS for the Next 3 Years:
# 2024: $9.99
# 2025: $10.96
# 2026: $11.93

# %%
# Get income statement data (focus on Operating Expense)
income_statement = hershey.financials
opex_data = income_statement.loc['Operating Expense'].transpose()

# Display the Operating Expense data
print("Hershey's Operating Expense Data (in dollars):")
print(opex_data)

# Check for NaN values in Operating Expense data
if opex_data.isnull().any():
    print("\nWarning: NaN values detected in Operating Expense data. Handling them...")
    opex_data = opex_data.dropna()  # Drop rows with NaN values
    # Alternatively, you could fill NaN values with the mean or median:
    # opex_data = opex_data.fillna(opex_data.mean())

# Prepare data for regression
# Convert index to datetime for better handling
opex_data.index = pd.to_datetime(opex_data.index)
opex_data = opex_data.sort_index()

# Create a numerical index for regression
X = np.array(range(len(opex_data))).reshape(-1, 1)  # Independent variable (time)
y = opex_data.values  # Dependent variable (Operating Expense)

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict future Operating Expenses (for the next 3 years)
future_X = np.array(range(len(opex_data), len(opex_data) + 3)).reshape(-1, 1)  # Next 3 years
predicted_opex = model.predict(future_X)

# Combine historical and predicted Operating Expenses
future_dates = pd.date_range(start=opex_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
predicted_opex_series = pd.Series(predicted_opex, index=future_dates)

# Plot historical and predicted Operating Expenses
plt.figure(figsize=(10, 5))
plt.plot(opex_data.index, opex_data.values, label='Historical Operating Expense', marker='o')
plt.plot(predicted_opex_series.index, predicted_opex_series.values, label='Predicted Operating Expense', marker='o', linestyle='--')
plt.title("Hershey's Operating Expense Prediction")
plt.xlabel("Year")
plt.ylabel("Operating Expense (in dollars)")
plt.legend()
plt.grid()
plt.show()

# Print predicted Operating Expenses
print("\nPredicted Operating Expense for the Next 3 Years:")
for year, opex in zip(predicted_opex_series.index.year, predicted_opex_series.values):
    print(f"{year}: ${opex:.2f}")
# Out:
# Hershey's Operating Expense Data (in dollars):
# 2024-12-31    2373621000.0
# 2023-12-31    2436508000.0
# 2022-12-31    2236009000.0
# 2021-12-31    2006528000.0
# 2020-12-31             NaN
# Name: Operating Expense, dtype: object
#
# Warning: NaN values detected in Operating Expense data. Handling them...
# C:\Users\rober\AppData\Local\Temp\ipykernel_21188\1957950135.py:34: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   future_dates = pd.date_range(start=opex_data.index[-1] + pd.DateOffset(years=1), periods=3, freq='Y')
# Predicted Operating Expense for the Next 3 Years:
# 2025: $2588611000.00
# 2026: $2718788800.00
# 2027: $2848966600.00

# %% [markdown]
# # Balance Sheet

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd  # Import pandas

# Define the ticker symbol for Apple Inc.
ticker_symbol = 'HSY'

# Fetch the data
hershey = yf.Ticker(ticker_symbol)

# Get the balance sheet
balance_sheet = hershey.balance_sheet

# Transpose the DataFrame to make it easier to work with
balance_sheet = balance_sheet.transpose()

# Select important items
important_items = ['Total Assets', 'Total Liabilities Net Minority Interest']
selected_data = balance_sheet[important_items]

# Convert the index to datetime
selected_data.index = pd.to_datetime(selected_data.index)

# Plotting Total Assets and Total Liabilities
plt.figure(figsize=(12, 6))
for item in important_items:
    plt.plot(selected_data.index, selected_data[item], marker='o', label=item)

plt.title(f'Balance Sheet Items Over Time for {ticker_symbol}')
plt.xlabel('Date')
plt.ylabel('Amount in $')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plotting Ordinary Shares Number in a separate chart
ordinary_shares = balance_sheet['Total Liabilities Net Minority Interest'].transpose()
ordinary_shares.index = pd.to_datetime(ordinary_shares.index)

plt.figure(figsize=(12, 6))
plt.plot(ordinary_shares.index, ordinary_shares, marker='o', color='orange', label='Total Liabilities Net Minority Interest')

plt.title(f'Total Liabilities Net Minority Interest for {ticker_symbol}')
plt.xlabel('Date')
plt.ylabel('$ Value (Billions)')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd  # Import pandas

# Define the ticker symbol for Apple Inc.
ticker_symbol = 'HSY'

# Fetch the data
hershey = yf.Ticker(ticker_symbol)

# Get the balance sheet
balance_sheet = hershey.balance_sheet

# Transpose the DataFrame to make it easier to work with
balance_sheet = balance_sheet.transpose()

# Select important items
important_items = ['Total Assets', 'Cash Cash Equivalents And Short Term Investments']
selected_data = balance_sheet[important_items]

# Convert the index to datetime
selected_data.index = pd.to_datetime(selected_data.index)

# Plotting Total Assets and Cash, Cash Equivalents, and Short-Term Investments
plt.figure(figsize=(12, 6))
for item in important_items:
    plt.plot(selected_data.index, selected_data[item], marker='o', label=item)

plt.title(f'Balance Sheet Items Over Time for {ticker_symbol}')
plt.xlabel('Date')
plt.ylabel('Amount in $')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plotting Ordinary Shares Number in a separate chart
ordinary_shares = balance_sheet['Cash Cash Equivalents And Short Term Investments'].transpose()
ordinary_shares.index = pd.to_datetime(ordinary_shares.index)

plt.figure(figsize=(12, 6))
plt.plot(ordinary_shares.index, ordinary_shares, marker='o', color='orange', label='Cash Cash Equivalents And Short Term Investments')

plt.title(f'Cash Cash Equivalents And Short Term Investments Over Time for {ticker_symbol}')
plt.xlabel('Date')
plt.ylabel('$ Value (Billions)')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd  # Import pandas

# Define the ticker symbol for Apple Inc.
ticker_symbol = 'HSY'

# Fetch the data
hershey = yf.Ticker(ticker_symbol)

# Get the balance sheet
balance_sheet = hershey.balance_sheet

# Transpose the DataFrame to make it easier to work with
balance_sheet = balance_sheet.transpose()

# Select important items
important_items = ['Total Assets', 'Net Debt']
selected_data = balance_sheet[important_items]

# Convert the index to datetime
selected_data.index = pd.to_datetime(selected_data.index)

# Plotting Total Assets and Net Debt
plt.figure(figsize=(12, 6))
for item in important_items:
    plt.plot(selected_data.index, selected_data[item], marker='o', label=item)

plt.title(f'Balance Sheet Items Over Time for {ticker_symbol}')
plt.xlabel('Date')
plt.ylabel('Amount in $')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plotting Ordinary Shares Number in a separate chart
ordinary_shares = balance_sheet['Net Debt'].transpose()
ordinary_shares.index = pd.to_datetime(ordinary_shares.index)

plt.figure(figsize=(12, 6))
plt.plot(ordinary_shares.index, ordinary_shares, marker='o', color='orange', label='Net Debt')

plt.title(f'Net Debt Number Over Time for {ticker_symbol}')
plt.xlabel('Date')
plt.ylabel('$ Value (Billions)')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Financial Ratios

# %%
# Look at Financial Ratios

import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd  # Import pandas

# Define the ticker symbol for Apple Inc.
ticker_symbol = 'HSY'

# Fetch the data
hershey = yf.Ticker(ticker_symbol)

# Get the balance sheet and income statement
balance_sheet = hershey.balance_sheet.transpose()
income_statement = hershey.financials.transpose()

# Convert the index to datetime for easier plotting
balance_sheet.index = pd.to_datetime(balance_sheet.index)
income_statement.index = pd.to_datetime(income_statement.index)

# Select important items for calculations
total_assets = balance_sheet['Total Assets']
total_liabilities = balance_sheet['Total Liabilities Net Minority Interest']
shareholder_equity = total_assets - total_liabilities  # Calculate Shareholder's Equity

net_income = income_statement['Net Income']
ordinary_shares = balance_sheet['Ordinary Shares Number']

# Calculate metrics
leverage_ratio = total_liabilities / total_assets
roe = net_income / shareholder_equity
eps = net_income / ordinary_shares

# Create a DataFrame for metrics
metrics = pd.DataFrame({
    'Leverage Ratio': leverage_ratio,
    'Return on Equity (ROE)': roe,
    'Earnings Per Share (EPS)': eps
})

# Plotting Leverage Ratio
plt.figure(figsize=(12, 6))
plt.plot(metrics.index, metrics['Leverage Ratio'], marker='o', color='blue')
plt.title(f'Leverage Ratio Over Time for {ticker_symbol}')
plt.xlabel('Date')
plt.ylabel('Leverage Ratio')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# Plotting Return on Equity (ROE)
plt.figure(figsize=(12, 6))
plt.plot(metrics.index, metrics['Return on Equity (ROE)'], marker='o', color='green')
plt.title(f'Return on Equity (ROE) Over Time for {ticker_symbol}')
plt.xlabel('Date')
plt.ylabel('Return on Equity (ROE)')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# Plotting Earnings Per Share (EPS)
plt.figure(figsize=(12, 6))
plt.plot(metrics.index, metrics['Earnings Per Share (EPS)'], marker='o', color='orange')
plt.title(f'Earnings Per Share (EPS) Over Time for {ticker_symbol}')
plt.xlabel('Date')
plt.ylabel('Earnings Per Share (EPS)')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Financial Analysis of FactSet Data

# %%
# download the estimates history and ratio analysis from Factset. You may want to use Python 3.9.6
# I rename the Excel of estimates history as "EPSestimates", and the file of ratio analysis as "Ratios"
# !pip install openpyxl
import pandas as pd

# Load Excel file, skipping the first 7 rows and using row 8 as header
df = pd.read_excel("Hershey True EPS.xlsx", skiprows=7)

# Transpose the data
df_transposed = df.transpose()

# Set first row as new headers
df_transposed.columns = df_transposed.iloc[0]
df_transposed = df_transposed[1:]

# Reset index to make the transposed index (original column headers) into a column
df_transposed = df_transposed.reset_index()

# Rename the first column to 'Date' — this is the old index
df_transposed.rename(columns={df_transposed.columns[0]: 'Date'}, inplace=True)

print(df_transposed['Date'].unique())
# Out:
# Requirement already satisfied: openpyxl in c:\users\rober\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\rober\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# ["DEC '24" "SEP '24" "JUN '24" "MAR '24" "DEC '23" "SEP '23" "JUN '23"
#  "MAR '23" "DEC '22" "SEP '22" "JUN '22" "MAR '22" "DEC '21" "SEP '21"
#  "JUN '21" "MAR '21" "DEC '20" "SEP '20" "JUN '20" "MAR '20" "DEC '19"
#  "SEP '19" "JUN '19" "MAR '19" "DEC '18"]

# %%
# Clean and normalize the date strings
df_transposed['Date'] = (
    df_transposed['Date']
    .astype(str)
    .str.strip()
    .str.replace(r"[’‘`]", "'", regex=True)
    .str.upper()
)

# Convert from "DEC '24" to datetime
df_transposed['Date'] = pd.to_datetime(df_transposed['Date'], format="%b '%y", errors='coerce')

# Sort by date
df_transposed = df_transposed.sort_values(by='Date')
# Drop columns with missing values
df_transposed = df_transposed.dropna(axis=1, how='all')

# Preview the result
print(df_transposed.head())
# Out:
# Unnamed: 0       Date  NaN Gross Margin SG&A to Sales Operating Margin  \
# 24         2018-12-01  LTM    45.144883     23.425566        21.719317
# 23         2019-03-01  LTM    45.009073     23.232904        21.776168
# 22         2019-06-01  LTM    45.157224      23.26075        21.896474
# 21         2019-09-01  LTM    45.011206     23.584305        21.426901
# 20         2019-12-01  LTM    44.914561     23.786515        21.128046
#
# Unnamed: 0 Pretax Margin Net Margin Free Cash Flow Margin  \
# 24             18.098428  15.114255             16.318582
# 23             17.315386  14.443275             15.526754
# 22             18.594954  15.509756              16.65334
# 21             19.104825  16.181271             17.411181
# 20             17.289512  14.395889             18.102121
#
# Unnamed: 0 Free Cash Flow Conversion Ratio Capex To Sales  ... CFO/Total Debt  \
# 24                               60.198189       4.217663  ...       0.358936
# 23                               56.721778       4.610778  ...        0.34165
# 22                               58.911129       4.699307  ...       0.385275
# 21                               60.656799       4.097961  ...       0.358865
# 20                               72.660243       3.984247  ...       0.393734
#
# Unnamed: 0 EBITDA-Capex/Interest Expense LT Debt/Total Equity  \
# 24                             11.637407           232.661124
# 23                             10.898076           241.454984
# 22                             10.823358           184.029084
# 21                             11.108891           175.754266
# 20                             11.193356           213.599874
#
# Unnamed: 0 LT Debt/Total Capital LT Debt/Total Assets  \
# 24                     55.568713            42.246807
# 23                     56.619247            43.474475
# 22                     51.153426            39.554555
# 21                     47.464051            36.403147
# 20                     59.735147            45.636311
#
# Unnamed: 0 Total Debt/Total Assets (%) Net Debt/Total Equity (%)  \
# 24                           57.868161                276.652599
# 23                           58.778707                293.517382
# 22                           55.831687                 237.91209
# 21                           55.983725                253.026931
# 20                           55.032428                229.217144
#
# Unnamed: 0 Total Debt/Equity (%) Net Debt/Total Capital  \
# 24                    318.690861              66.075624
# 23                    326.453892               68.82746
# 22                    259.759062              66.130951
# 21                    270.289226              68.332242
# 20                    257.578216              64.102659
#
# Unnamed: 0 Total Debt/Total Capital
# 24                         76.11603
# 23                        76.550806
# 22                        72.203619
# 21                        72.994083
# 20                        72.034091
#
# [5 rows x 93 columns]

# %%
#import estimates
import pandas as pd

# Load the Excel file "EPSestimates", skipping the first 2 rows and using the third row as header
df_eps = pd.read_excel("Hershey EPS.xlsx", skiprows=2)

# Convert the "Date" column with the format "07 Apr '25" to datetime
df_eps['Date'] = pd.to_datetime(df_eps['Date'], format="%d %b '%y", errors='coerce')

# Sort by date
df_eps = df_eps.sort_values(by='Date')

# Rename the column 'Mean' to 'EPS estimate'
df_eps = df_eps.rename(columns={'Mean': 'EPS estimate'})

# View the first few rows after conversion
print(df_eps.tail())
# Out:
#         Date EPS estimate Num of Est Num Up Num Down   Low   High   Std Dev  \
# 4 2024-12-31      8.10711         23      0       23  6.84  10.04  0.617426
# 3 2025-01-31      7.35436         23      0       22  5.79  10.04  0.867564
# 2 2025-02-28      6.16784         23      2       21  6.02    7.3  0.252797
# 1 2025-03-31      6.15798         24      2       21  6.02    7.3  0.249852
# 0 2025-04-14       6.1505         23      2       20  6.02    7.3  0.255819
#
#     Chg (%)   Chg Amt  P/E (x) PEG (x)
# 4  -1.66922 -0.137623  20.8891       -
# 3  -9.28507  -0.75275  20.2941       -
# 2  -16.1336  -1.18652  28.0017       -
# 1 -0.159793 -0.009856  27.7737       -
# 0 -0.121517 -0.007483  27.6888       -

# %%
# Extract year and month from the 'Date' column of both DataFrames
df_eps['Year'] = df_eps['Date'].dt.year
df_eps['Month'] = df_eps['Date'].dt.month

df_transposed['Year'] = df_transposed['Date'].dt.year
df_transposed['Month'] = df_transposed['Date'].dt.month

# Merge the two DataFrames on Year and Month
merged_df = pd.merge(df_eps, df_transposed, on=['Year', 'Month'], how='inner')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert both columns to numeric, coercing any bad strings to NaN
merged_df['EPS (basic)'] = pd.to_numeric(merged_df['EPS (basic)'], errors='coerce')
merged_df['EPS estimate'] = pd.to_numeric(merged_df['EPS estimate'], errors='coerce')

# Calculate the difference
merged_df['EPS Difference'] = merged_df['EPS (basic)'] - merged_df['EPS estimate']

# Sort by date for proper plotting
merged_df = merged_df.sort_values(by='Date_y')

# Plot
plt.figure(figsize=(12, 6))
plt.plot(merged_df['Date_y'], merged_df['EPS (basic)'], label='EPS (basic)', marker='o')
plt.plot(merged_df['Date_y'], merged_df['EPS estimate'], label='EPS estimate', marker='x')
plt.xlabel('Date')
plt.ylabel('EPS')
plt.title('EPS (basic) vs EPS Estimate Over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 5))
plt.bar(merged_df['Date_y'], merged_df['EPS Difference'], color='orange')
plt.xlabel('Date_y')
plt.ylabel('EPS Difference')
plt.title('Difference Between EPS (basic) and EPS Estimate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Avoid division by zero by filtering out zero estimates
merged_df['EPS Surprise (%)'] = ((merged_df['EPS (basic)'] - merged_df['EPS estimate']) / merged_df['EPS estimate'].abs()) * 100
plt.figure(figsize=(12, 5))
plt.bar(merged_df['Date_y'], merged_df['EPS Surprise (%)'], color='teal')
plt.axhline(0, color='gray', linestyle='--')
plt.title('EPS Surprise (%) Over Time')
plt.xlabel('Date')
plt.ylabel('EPS Surprise (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
